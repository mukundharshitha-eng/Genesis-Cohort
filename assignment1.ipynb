-- %%
REPLACE TABLE Customers(
    CustomerID INT,
    CustomerName STRING,
    City STRING,
    AccountType STRING,
    Balance INT,
    LoanAmount INT
    );
    insert into Customers values
    (101,'John','Dallas','Savings',5000,10000),
    (102,'Mary','Austin','Current',2500,5000),
    (103,'David','Dallas','Savings',8000,0),
    (104,'Emma','Houston','Savings',1500,3000),
    (105,'Alex','Austin','Current',7000,12000),
    (106,'Sophia','Dallas','Savings',5000,8000);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>6</td><td>6</td></tr></tbody></table></div>

-- %%
SELECT CustomerName, City, Balance, LoanAmount
FROM Customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerName</th><th>City</th><th>Balance</th><th>LoanAmount</th></tr></thead><tbody><tr><td>John</td><td>Dallas</td><td>5000</td><td>10000</td></tr><tr><td>Mary</td><td>Austin</td><td>2500</td><td>5000</td></tr><tr><td>David</td><td>Dallas</td><td>8000</td><td>0</td></tr><tr><td>Emma</td><td>Houston</td><td>1500</td><td>3000</td></tr><tr><td>Alex</td><td>Austin</td><td>7000</td><td>12000</td></tr><tr><td>Sophia</td><td>Dallas</td><td>5000</td><td>8000</td></tr></tbody></table></div>

-- %%
SELECT DISTINCT City
FROM Customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>City</th></tr></thead><tbody><tr><td>Dallas</td></tr><tr><td>Austin</td></tr><tr><td>Houston</td></tr></tbody></table></div>

-- %%
SELECT CustomerName, City, Balance, LoanAmount
FROM Customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerName</th><th>City</th><th>Balance</th><th>LoanAmount</th></tr></thead><tbody><tr><td>John</td><td>Dallas</td><td>5000</td><td>10000</td></tr><tr><td>Mary</td><td>Austin</td><td>2500</td><td>5000</td></tr><tr><td>David</td><td>Dallas</td><td>8000</td><td>0</td></tr><tr><td>Emma</td><td>Houston</td><td>1500</td><td>3000</td></tr><tr><td>Alex</td><td>Austin</td><td>7000</td><td>12000</td></tr><tr><td>Sophia</td><td>Dallas</td><td>5000</td><td>8000</td></tr></tbody></table></div>

-- %%
SELECT *
FROM Customers
ORDER BY LoanAmount DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th>CustomerName</th><th>City</th><th>AccountType</th><th>Balance</th><th>LoanAmount</th></tr></thead><tbody><tr><td>105</td><td>Alex</td><td>Austin</td><td>Current</td><td>7000</td><td>12000</td></tr><tr><td>101</td><td>John</td><td>Dallas</td><td>Savings</td><td>5000</td><td>10000</td></tr><tr><td>106</td><td>Sophia</td><td>Dallas</td><td>Savings</td><td>5000</td><td>8000</td></tr><tr><td>102</td><td>Mary</td><td>Austin</td><td>Current</td><td>2500</td><td>5000</td></tr><tr><td>104</td><td>Emma</td><td>Houston</td><td>Savings</td><td>1500</td><td>3000</td></tr><tr><td>103</td><td>David</td><td>Dallas</td><td>Savings</td><td>8000</td><td>0</td></tr></tbody></table></div>

-- %%
SELECT COUNT(*) AS Total_Loan
FROM Customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total_Loan</th></tr></thead><tbody><tr><td>6</td></tr></tbody></table></div>

-- %%
SELECT SUM(LoanAmount) AS Total_Loan
FROM Customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total_Loan</th></tr></thead><tbody><tr><td>38000</td></tr></tbody></table></div>

-- %%
SELECT MIN(Balance) AS Minimum_Balance
FROM Customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Minimum_Balance</th></tr></thead><tbody><tr><td>1500</td></tr></tbody></table></div>

-- %%
SELECT MAX(Balance) AS Maximum_Balance
FROM Customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Maximum_Balance</th></tr></thead><tbody><tr><td>8000</td></tr></tbody></table></div>

-- %%
SELECT AVG(Balance) AS Average_Balance
FROM Customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Average_Balance</th></tr></thead><tbody><tr><td>4833.333333333333</td></tr></tbody></table></div>

-- %%
SELECT *
FROM Customers
ORDER BY LoanAmount DESC
LIMIT 5;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th>CustomerName</th><th>City</th><th>AccountType</th><th>Balance</th><th>LoanAmount</th></tr></thead><tbody><tr><td>105</td><td>Alex</td><td>Austin</td><td>Current</td><td>7000</td><td>12000</td></tr><tr><td>101</td><td>John</td><td>Dallas</td><td>Savings</td><td>5000</td><td>10000</td></tr><tr><td>106</td><td>Sophia</td><td>Dallas</td><td>Savings</td><td>5000</td><td>8000</td></tr><tr><td>102</td><td>Mary</td><td>Austin</td><td>Current</td><td>2500</td><td>5000</td></tr><tr><td>104</td><td>Emma</td><td>Houston</td><td>Savings</td><td>1500</td><td>3000</td></tr></tbody></table></div>
